# %% [markdown]
# <a href="https://colab.research.google.com/github/DARIOYBETY123/Modulo-4-Deep-Leraning/blob/main/Optimizaci%C3%B3n_no_terminado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Optimización

# %% [markdown]
# Mostrar cómo funciona el descenso por gradiente paso a paso sobre un modelo Gabor 1D, visualizando:
#
# La superficie de pérdida
#
# La trayectoria de los parámetros durante el entrenamiento
#
# Cómo mejora el ajuste del modelo a los datos
#
# La pérdida y los valores de los parámetros en cada paso

# %% [markdown]
# Función tipo Gabor (onda sinusoidal multiplicada por una campana gaussiana)

# %%
import numpy as np

# Prueba 1: tasa demasiado alta → diverge
lr = 15.0

# Prueba 2: tasa baja → avanza lento
lr = 1.0

# Prueba 3: empieza cerca → converge rápido
phi = np.array([2.5, 14.0])
